# %%
import torch
import sys
import os

sys.path.append('..')

# %%
from torch.utils.data import DataLoader

from dataset import get_dataset
from datasets.gqn import Scene
from models import get_model_genesis as get_model
from preprocess import Dummy, Quantization, Range

from torchvision.utils import make_grid
from matplotlib.pyplot import imshow, figure, scatter, colorbar, hist
import matplotlib.pyplot as plt
import matplotlib as mpl

use_gpu = torch.cuda.is_available()
device = torch.device('cuda' if use_gpu else 'cpu')
num_gpus = torch.cuda.device_count()

# %%
# Get dataset
dataset = 'rooms_ring_camera'
data_root = '/data/public/rw/datsets/gqn/torch'
batch_size = 32
data = get_dataset(dataset, data_root, batch_size)

kwargs = {
    'pin_memory': True if use_gpu else False,
    'shuffle': False,
    'num_workers': num_gpus * 4
}

loader = DataLoader(data['test'], batch_size * num_gpus, **kwargs)

# %%
data1, _ = data['train'][0]
dims = list(data1.shape)
param = dict(
    zdim=64,
    hdim=128,
    quant=False,
    layers=4,
    sigma=0.7
)
model, optimizaer = get_model('genesis', 1e-4, param, *dims)
q = Dummy()

def view_image(img):
    imshow(img.cpu().numpy().transpose(1,2,0))
    
def view_images(t):
    t_grid = make_grid(t,nrow=3)
    imshow(t_grid.cpu().numpy().transpose(1,2,0),interpolation='nearest')

# %%
logroot = '/data/private/exp/genesis/rooms_ring_camera_vae'
log = 'modelgenesis_batch_size128_epoch300_num_gpu4_lr0.0001_zdim64_hdim128_quantFalse_layers4_sigma0.7/Dec02-1929'
log = 'modelgenesis_batch_size128_epoch300_num_gpu4_lr0.0001_zdim64_hdim128_quantFalse_layers7_sigma0.7_new_nll/Dec04-1741'
filename = 'checkpoints/epoch_model_125.pth'
filepath = os.path.join(logroot, log, filename)
saved = torch.load(filepath)
model.load_state_dict(saved)
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %%
model.eval()
model.to(device)
# Out:
# Genesis(
#   (mask_vae): GatedRecurrentSBP(
#     (core): VAE(
#       (q_z_nn): Sequential(
#         (0): GatedConv2d(
#           (sigmoid): Sigmoid()
#           (conv): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           (h_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (g_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): GatedConv2d(
#           (sigmoid): Sigmoid()
#           (conv): Conv2d(32, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#           (h_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (g_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): GatedConv2d(
#           (sigmoid): Sigmoid()
#           (conv): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           (h_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (g_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (3): GatedConv2d(
#           (sigmoid): Sigmoid()
#           (conv): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#           (h_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (g_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (4): GatedConv2d(
#           (sigmoid): Sigmoid()
#           (conv): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           (h_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (g_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (5): GatedConv2d(
#           (sigmoid): Sigmoid()
#           (conv): Conv2d(64, 256, kernel_size=(16, 16), stride=(1, 1))
#         )
#       )
#       (q_z_mean): Linear(in_features=128, out_features=64, bias=True)
#       (q_z_var): Sequential(
#         (0): Linear(in_features=128, out_features=64, bias=True)
#       )
#       (p_x_nn): Sequential(
#         (0): GatedConvTranspose2d(
#           (sigmoid): Sigmoid()
#           (conv): ConvTranspose2d(64, 128, kernel_size=(16, 16), stride=(1, 1))
#         )
#         (1): GatedConvTranspose2d(
#           (sigmoid): Sigmoid()
#           (conv): ConvTranspose2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           (h_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (g_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): GatedConvTranspose2d(
#           (sigmoid): Sigmoid()
#           (conv): ConvTranspose2d(64, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#           (h_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (g_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (3): GatedConvTranspose2d(
#           (sigmoid): Sigmoid()
#           (conv): ConvTranspose2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           (h_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (g_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (4): GatedConvTranspose2d(
#           (sigmoid): Sigmoid()
#           (conv): ConvTranspose2d(32, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#           (h_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (g_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (5): GatedConvTranspose2d(
#           (sigmoid): Sigmoid()
#           (conv): ConvTranspose2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           (h_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (g_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (p_x_mean): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (posterior_lstm): LSTM(192, 128)
#     (posterior_linear): Linear(in_features=128, out_features=128, bias=True)
#     (prior_lstm): LSTM(64, 128)
#     (prior_linear): Linear(in_features=128, out_features=128, bias=True)
#   )
#   (component_vae): ComponentVAE(
#     (posterior_encoder): ComponentEncoder(
#       (conv1): Conv2d(4, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv4): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (mlp1): Linear(in_features=2048, out_features=128, bias=True)
#       (mlp2): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (prior_encoder): ComponentEncoder(
#       (conv1): Conv2d(1, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv4): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (mlp1): Linear(in_features=2048, out_features=128, bias=True)
#       (mlp2): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (decoder): SpatialBroadcastDecoder(
#       (conv1): Conv2d(66, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv5): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
# )

# %%
with torch.no_grad():
    x, _ = data['test'][0]
    x = x.view(1, 3, 64, 64)
    x_p = q.preprocess(x)
    x_p = x_p.to(device)
    recon_p, recon_k_p, x_mu_k, ms_k, kl_m, kl_c = model(x_p)
    recon = q.postprocess(recon_p)
    recon_k = q.postprocess(recon_k_p)

# %%
mpl.rcParams['figure.dpi'] = 50
view_image(x.view(3, 64, 64))

# %%
mpl.rcParams['figure.dpi'] = 50
view_image(recon.view(3, 64, 64))

# %%
mpl.rcParams['figure.dpi'] = 50

view_images(recon_k.squeeze(0).permute(3, 0, 1, 2))

# %%
mpl.rcParams['figure.dpi'] = 50
view_images(x_mu_k.squeeze(0).permute(3, 0, 1, 2))

# %%
mpl.rcParams['figure.dpi'] = 50
view_images(ms_k.exp().squeeze(0).permute(3, 0, 1, 2))

# %%
ms_1 = ms_k[0, 0, :, :, 0].exp()
print(ms_1.shape)
hist(ms_1.view(-1).cpu().numpy(),100)
# Out:
# torch.Size([64, 64])
# (array([1.600e+03, 1.600e+01, 1.000e+00, 2.000e+00, 1.000e+00, 3.000e+00,
#         1.000e+00, 1.000e+00, 2.000e+00, 3.000e+00, 4.000e+00, 0.000e+00,
#         2.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 3.000e+00, 1.000e+00,
#         1.000e+00, 0.000e+00, 2.000e+00, 2.000e+00, 0.000e+00, 0.000e+00,
#         2.000e+00, 2.000e+00, 4.000e+00, 0.000e+00, 2.000e+00, 1.000e+00,
#         2.000e+00, 4.000e+00, 3.000e+00, 2.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,